# %% [markdown]
# <a href="https://colab.research.google.com/github/shivaniguleria97/Bank-Customer-Churn-Prediction/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MINI PROJECT**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('churn_prediction.csv')

# %%
data.head()

# %%
cors = data.corr(numeric_only=True)
sns.heatmap(cors)

# %%
sns.boxplot(x="churn",y="age",data=data)
plt.show()

# %%
sns.boxplot(x="churn",y="credit_score",data=data)

# %%
plt.scatter(data['balance'],data['estimated_salary'])

# %%
data["gender"].value_counts()

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['encoded'] = encoder.fit_transform(data["gender"])
# 1 for male & 0 for female etc.
data[['churn','encoded']].head()

# %%
data['encoded'].value_counts()

# %%
m_values=5457
f_values=4543
m_churn,f_churn=0,0
for i in range(0,len(data)):
    if (data['churn'][i]==1 and data['encoded'][i]==1):
        m_churn+=1
    elif (data['churn'][i]==1 and data['encoded'][i]==0):
        f_churn+=1

# %%
x=[m_churn,f_churn]
print(x)

# %%
plt.bar(['male','female'],[m_churn,f_churn])

# %%
y=data['churn']
x=data[['age','credit_score','encoded','tenure','balance','products_number','credit_card','active_member','estimated_salary']]

# %%
x_tr,x_ts,y_tr,y_ts=train_test_split(x,y,test_size=0.2)
from sklearn.preprocessing  import StandardScaler
scaling=StandardScaler()
scaling.fit_transform(x_tr)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=1000)
model.fit(x_tr,y_tr)
model.score(x_ts,y_ts)

# %%
model.coef_

# %%
from sklearn.pipeline import make_pipeline
test_scores=[]
for lam in np.arange(0.01,100,0.1):
    pipe=make_pipeline(StandardScaler(),LogisticRegression(C=1/lam))
    pipe.fit(x_tr,y_tr)
    scores=pipe.score(x_ts,y_ts)
    test_scores.append(scores)

# %%
plt.plot(test_scores)

# %%
np.argmax(test_scores)

# %%
lam_best=0.01*624*0.1
